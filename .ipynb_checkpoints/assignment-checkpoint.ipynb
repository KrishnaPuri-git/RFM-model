# %%
#importing all relevant liabraries

import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.options.display.max_columns=None
import seaborn as sns
import plotly.express as px

import datetime as dt
from tqdm import tqdm
import time

from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
from math import isnan
 

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree
import scipy.stats as stats

# %%
df=pd.read_excel('sales_data.xlsx')

# %%
df.head(10)
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0          22           124  11986.54                96.67            529.59
# 1          29            82  11025.96               134.46             97.92
# 2          83            43   7259.69               168.83            171.69
# 3          95            44   6992.27               158.92             92.82
# 4         124            55   6263.44               113.88            179.04
# 5         153            49   5841.24               119.21             96.84
# 6         187            43   5470.27               127.22            128.77
# 7         219            54   5200.53                96.31            237.53
# 8         258            19   4967.06               261.42             51.91
# 9         308            21   4726.38               225.07             63.88
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
# 5             1.98       2015-07-26        2021-10-24                 46.57
# 6             2.99       2019-01-14        2021-10-24                 23.58
# 7             4.40       2019-11-19        2021-10-24                 13.06
# 8             2.73       2021-03-03        2021-10-24                 12.37
# 9             3.04       2020-01-06        2021-10-24                 31.29
#
#    DAYSSINCELASTORDER  MONDAY_ORDERS  TUESDAY_ORDERS  WEDNESDAY_ORDERS  \
# 0                   1             13              13                29
# 1                   1             11              13                10
# 2                   1              5               4                 3
# 3                   1             10               8                 5
# 4                   1              2               3                 8
# 5                   1              6               7                 9
# 6                   1              5               6                 3
# 7                   1             17               5                 7
# 8                   1              4               6                 5
# 9                   1              1               2                 9
#
#    THURSDAY_ORDERS  FRIDAY_ORDERS  SATURDAY_ORDERS  SUNDAY_ORDERS  \
# 0               25             19               15             10
# 1               13             14               10             11
# 2                5              5                8             13
# 3                8              5                3              5
# 4                8             12               10             12
# 5                8              6                7              6
# 6                3             11                7              8
# 7                4              5                9              7
# 8                2              0                0              2
# 9                2              3                1              3
#
#    MONDAY_REVENUE  TUESDAY_REVENUE  WEDNESDAY_REVENUE  THURSDAY_REVENUE  \
# 0         1287.50          1054.15            2842.52           2133.79
# 1         1253.08          2003.25            1819.75           1114.83
# 2          698.95           504.97             197.97           1182.97
# 3         1753.95          1400.23             570.48           1154.06
# 4          150.98           330.38            1090.23            563.63
# 5          563.98           601.00             895.48            818.96
# 6          395.70           964.58             588.98            798.97
# 7         1612.17           492.45             595.04            458.96
# 8         1930.60          1323.97             533.37            474.19
# 9           36.00           422.99            1732.94            922.48
#
#    FRIDAY_REVENUE  SATURDAY_REVENUE  SUNDAY_REVENUE  WEEK1_DAY01_DAY07_ORDERS  \
# 0         2051.94           1496.33         1120.31                        28
# 1         1791.86           1624.34         1418.85                        18
# 2          733.96           1223.96         2716.91                         9
# 3          798.07            630.00          685.48                        12
# 4         1339.44            956.56         1832.22                        10
# 5          929.47           1255.87          776.48                        11
# 6         1175.54            517.87         1028.63                         3
# 7          350.15           1120.52          571.24                        10
# 8            0.00              0.00          704.93                         7
# 9          626.99            333.00          651.98                         7
#
#    WEEK2_DAY08_DAY15_ORDERS  WEEK3_DAY16_DAY23_ORDERS  \
# 0                        42                        30
# 1                        19                        19
# 2                        11                         6
# 3                        15                         9
# 4                        18                        21
# 5                        11                        14
# 6                         2                        16
# 7                        19                        10
# 8                         2                         9
# 9                         4                         5
#
#    WEEK4_DAY24_DAY31_ORDERS  WEEK1_DAY01_DAY07_REVENUE  \
# 0                        24                    2685.37
# 1                        26                    1336.09
# 2                        17                    2299.93
# 3                         8                    2317.95
# 4                         6                     831.14
# 5                        13                    1470.95
# 6                        22                     611.49
# 7                        15                     983.11
# 8                         1                    1431.95
# 9                         5                    1318.95
#
#    WEEK2_DAY08_DAY15_REVENUE  WEEK3_DAY16_DAY23_REVENUE  \
# 0                    4299.28                    2592.18
# 1                    2776.02                    2807.66
# 2                    1383.92                     713.94
# 3                    2417.22                     997.02
# 4                    1938.18                    2725.66
# 5                    1326.36                    1595.97
# 6                     117.00                    2042.31
# 7                    2123.54                     754.72
# 8                     383.18                    2588.19
# 9                    1320.48                    1094.98
#
#    WEEK4_DAY24_DAY31_REVENUE  TIME_0000_0600_ORDERS  TIME_0601_1200_ORDERS  \
# 0                    2409.71                     12                     61
# 1                    4106.19                      1                     13
# 2                    2861.90                      0                      6
# 3                    1260.08                      0                     10
# 4                     768.46                      6                      9
# 5                    1447.96                      0                     20
# 6                    2699.47                      2                      0
# 7                    1339.16                      2                     22
# 8                     563.74                      1                      0
# 9                     991.97                      4                     11
#
#    TIME_1200_1800_ORDERS  TIME_1801_2359_ORDERS  TIME_0000_0600_REVENUE  \
# 0                     37                     14                 1067.92
# 1                     24                     44                   30.25
# 2                     12                     25                    0.00
# 3                     13                     21                    0.00
# 4                     27                     13                  501.34
# 5                     23                      6                    0.00
# 6                     19                     22                   47.00
# 7                     24                      6                  273.18
# 8                      8                     10                  332.19
# 9                      6                      0                 1095.98
#
#    TIME_0601_1200_REVENUE  TIME_1200_1800_REVENUE  TIME_1801_2359_REVENUE  \
# 0                 5674.65                 3916.53                 1327.44
# 1                 3143.69                 2205.47                 5646.55
# 2                  707.98                 2560.91                 3990.80
# 3                 1908.99                 2025.05                 3058.23
# 4                 1197.83                 3004.77                 1559.50
# 5                 2482.33                 2759.43                  599.48
# 6                    0.00                 2578.28                 2844.99
# 7                 2328.21                 1980.99                  618.15
# 8                    0.00                 1673.10                 2961.77
# 9                 1867.94                 1762.46                    0.00
#
#    Unnamed: 40  Unnamed: 41
# 0          NaN          NaN
# 1          NaN     33340.77
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN

# %% [markdown]
# ##### Dataset Insights

# %%
df.shape
# Out:
# (5000, 42)

# %% [markdown]
# ##### Dataset Desciption
# The dataset folder contains the following files:
# train.csv: *5000, 40*

# %% [markdown]
# ##### EDA

# %% [markdown]
# Features names-

# %%
# get all column names
df.columns
# Out:
# Index(['CustomerID', 'TOTAL_ORDERS', 'REVENUE', 'AVERAGE_ORDER_VALUE',
#        'CARRIAGE_REVENUE', 'AVERAGESHIPPING', 'FIRST_ORDER_DATE',
#        'LATEST_ORDER_DATE', 'AVGDAYSBETWEENORDERS', 'DAYSSINCELASTORDER',
#        'MONDAY_ORDERS', 'TUESDAY_ORDERS', 'WEDNESDAY_ORDERS',
#        'THURSDAY_ORDERS', 'FRIDAY_ORDERS', 'SATURDAY_ORDERS', 'SUNDAY_ORDERS',
#        'MONDAY_REVENUE', 'TUESDAY_REVENUE', 'WEDNESDAY_REVENUE',
#        'THURSDAY_REVENUE', 'FRIDAY_REVENUE', 'SATURDAY_REVENUE',
#        'SUNDAY_REVENUE', 'WEEK1_DAY01_DAY07_ORDERS',
#        'WEEK2_DAY08_DAY15_ORDERS', 'WEEK3_DAY16_DAY23_ORDERS',
#        'WEEK4_DAY24_DAY31_ORDERS', 'WEEK1_DAY01_DAY07_REVENUE',
#        'WEEK2_DAY08_DAY15_REVENUE', 'WEEK3_DAY16_DAY23_REVENUE',
#        'WEEK4_DAY24_DAY31_REVENUE', 'TIME_0000_0600_ORDERS',
#        'TIME_0601_1200_ORDERS', 'TIME_1200_1800_ORDERS',
#        'TIME_1801_2359_ORDERS', 'TIME_0000_0600_REVENUE',
#        'TIME_0601_1200_REVENUE', 'TIME_1200_1800_REVENUE',
#        'TIME_1801_2359_REVENUE', 'Unnamed: 40', 'Unnamed: 41'],
#       dtype='object')

# %% [markdown]
# Data type and count of features-

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 5000 non-null   int64
#  1   TOTAL_ORDERS               5000 non-null   int64
#  2   REVENUE                    5000 non-null   float64
#  3   AVERAGE_ORDER_VALUE        5000 non-null   float64
#  4   CARRIAGE_REVENUE           5000 non-null   float64
#  5   AVERAGESHIPPING            5000 non-null   float64
#  6   FIRST_ORDER_DATE           5000 non-null   datetime64[ns]
#  7   LATEST_ORDER_DATE          5000 non-null   datetime64[ns]
#  8   AVGDAYSBETWEENORDERS       5000 non-null   float64
#  9   DAYSSINCELASTORDER         5000 non-null   int64
#  10  MONDAY_ORDERS              5000 non-null   int64
#  11  TUESDAY_ORDERS             5000 non-null   int64
#  12  WEDNESDAY_ORDERS           5000 non-null   int64
#  13  THURSDAY_ORDERS            5000 non-null   int64
#  14  FRIDAY_ORDERS              5000 non-null   int64
#  15  SATURDAY_ORDERS            5000 non-null   int64
#  16  SUNDAY_ORDERS              5000 non-null   int64
#  17  MONDAY_REVENUE             5000 non-null   float64
#  18  TUESDAY_REVENUE            5000 non-null   float64
#  19  WEDNESDAY_REVENUE          5000 non-null   float64
#  20  THURSDAY_REVENUE           5000 non-null   float64
#  21  FRIDAY_REVENUE             5000 non-null   float64
#  22  SATURDAY_REVENUE           5000 non-null   float64
#  23  SUNDAY_REVENUE             5000 non-null   float64
#  24  WEEK1_DAY01_DAY07_ORDERS   5000 non-null   int64
#  25  WEEK2_DAY08_DAY15_ORDERS   5000 non-null   int64
#  26  WEEK3_DAY16_DAY23_ORDERS   5000 non-null   int64
#  27  WEEK4_DAY24_DAY31_ORDERS   5000 non-null   int64
#  28  WEEK1_DAY01_DAY07_REVENUE  5000 non-null   float64
#  29  WEEK2_DAY08_DAY15_REVENUE  5000 non-null   float64
#  30  WEEK3_DAY16_DAY23_REVENUE  5000 non-null   float64
#  31  WEEK4_DAY24_DAY31_REVENUE  5000 non-null   float64
#  32  TIME_0000_0600_ORDERS      5000 non-null   int64
#  33  TIME_0601_1200_ORDERS      5000 non-null   int64
#  34  TIME_1200_1800_ORDERS      5000 non-null   int64
#  35  TIME_1801_2359_ORDERS      5000 non-null   int64
#  36  TIME_0000_0600_REVENUE     5000 non-null   float64
#  37  TIME_0601_1200_REVENUE     5000 non-null   float64
#  38  TIME_1200_1800_REVENUE     5000 non-null   float64
#  39  TIME_1801_2359_REVENUE     5000 non-null   float64
#  40  Unnamed: 40                0 non-null      float64
#  41  Unnamed: 41                1 non-null      float64
# dtypes: datetime64[ns](2), float64(22), int64(18)
# memory usage: 1.6 MB

# %% [markdown]
# 1. After checking the Dtypes of all the columns
#     1. object - String values
#     1. float64 - Numerical values
# 1. There are more String values than the numerical values in the dataset

# %% [markdown]
# ##### The describe() method returns description of feature and their interrealtions-
#
# count - The number of not-empty values. <br>
# mean - The average (mean) value. <br>
# std - The standard deviation. <br>
# min - the minimum value. <br>
# 25% - The 25% percentile*. <br>
# 50% - The 50% percentile*. <br>
# 75% - The 75% percentile*. <br>
# max - the maximum value. <br>

# %%
df.describe()
# Out:
#           CustomerID  TOTAL_ORDERS       REVENUE  AVERAGE_ORDER_VALUE  \
# count    5000.000000    5000.00000   5000.000000          5000.000000
# mean    40709.227800      12.87040   1681.523840           136.537378
# std     49949.848017      12.67988   1998.618678            91.651569
# min         1.000000       1.00000     38.500000            10.680000
# 25%      1687.500000       3.00000    315.097500            83.025000
# 50%     13765.000000       8.00000    966.725000           113.160000
# 75%     71891.500000      20.00000   2493.072500           160.272500
# max    277160.000000     156.00000  34847.400000          1578.880000
#
#        CARRIAGE_REVENUE  AVERAGESHIPPING  AVGDAYSBETWEENORDERS  \
# count       5000.000000      5000.000000           5000.000000
# mean          46.036376         3.592574            163.159618
# std           47.879226         2.021360            259.699496
# min            0.000000         0.000000              0.000000
# 25%            9.980000         2.500000             21.670000
# 50%           24.985000         3.660000             57.635000
# 75%           76.862500         4.790000            170.357500
# max          529.590000        35.990000           1409.500000
#
#        DAYSSINCELASTORDER  MONDAY_ORDERS  TUESDAY_ORDERS  WEDNESDAY_ORDERS  \
# count         5000.000000    5000.000000      5000.00000       5000.000000
# mean            87.420000       1.629000         1.75440          1.798000
# std             80.156513       2.236506         2.43394          2.464875
# min              1.000000       0.000000         0.00000          0.000000
# 25%              7.000000       0.000000         0.00000          0.000000
# 50%             68.000000       1.000000         1.00000          1.000000
# 75%            171.250000       2.000000         3.00000          3.000000
# max            207.000000      19.000000        23.00000         29.000000
#
#        THURSDAY_ORDERS  FRIDAY_ORDERS  SATURDAY_ORDERS  SUNDAY_ORDERS  \
# count      5000.000000     5000.00000      5000.000000    5000.000000
# mean          2.134000        1.94620         1.683400       1.925400
# std           2.468048        2.65268         2.449972       2.315018
# min           0.000000        0.00000         0.000000       0.000000
# 25%           0.000000        0.00000         0.000000       0.000000
# 50%           1.000000        1.00000         1.000000       1.000000
# 75%           3.000000        3.00000         3.000000       3.000000
# max          32.000000       26.00000        31.000000      23.000000
#
#        MONDAY_REVENUE  TUESDAY_REVENUE  WEDNESDAY_REVENUE  THURSDAY_REVENUE  \
# count     5000.000000      5000.000000        5000.000000       5000.000000
# mean       215.208336       233.510430         235.689294        265.949796
# std        397.831999       411.941787         397.858311        383.890024
# min          0.000000         0.000000           0.000000          0.000000
# 25%          0.000000         0.000000           0.000000          0.000000
# 50%         74.990000        75.990000          80.990000        144.590000
# 75%        286.865000       310.972500         319.992500        344.357500
# max      12819.410000      7853.920000        5877.440000       6434.950000
#
#        FRIDAY_REVENUE  SATURDAY_REVENUE  SUNDAY_REVENUE  \
# count     5000.000000        5000.00000     5000.000000
# mean       250.580554         219.64210      260.943330
# std        400.543113         376.13976      406.926075
# min          0.000000           0.00000        0.000000
# 25%          0.000000           0.00000        0.000000
# 50%         91.195000          62.41500      135.990000
# 75%        352.740000         297.28000      341.367500
# max       6855.220000        4642.97000     8366.350000
#
#        WEEK1_DAY01_DAY07_ORDERS  WEEK2_DAY08_DAY15_ORDERS  \
# count                5000.00000               5000.000000
# mean                    2.99780                  3.062600
# std                     3.25698                  3.792461
# min                     0.00000                  0.000000
# 25%                     1.00000                  0.000000
# 50%                     2.00000                  2.000000
# 75%                     4.00000                  5.000000
# max                    32.00000                 42.000000
#
#        WEEK3_DAY16_DAY23_ORDERS  WEEK4_DAY24_DAY31_ORDERS  \
# count               5000.000000               5000.000000
# mean                   3.230000                  3.580000
# std                    3.921043                  3.970384
# min                    0.000000                  0.000000
# 25%                    0.000000                  1.000000
# 50%                    2.000000                  2.000000
# 75%                    5.000000                  5.000000
# max                   37.000000                 53.000000
#
#        WEEK1_DAY01_DAY07_REVENUE  WEEK2_DAY08_DAY15_REVENUE  \
# count                5000.000000                5000.000000
# mean                  378.638346                 406.595734
# std                   515.590218                 619.413277
# min                     0.000000                   0.000000
# 25%                    63.990000                   0.000000
# 50%                   190.985000                 183.925000
# 75%                   513.012500                 553.462500
# max                  8143.650000               11303.890000
#
#        WEEK3_DAY16_DAY23_REVENUE  WEEK4_DAY24_DAY31_REVENUE  \
# count                5000.000000                5000.000000
# mean                  421.826908                 474.462852
# std                   643.449120                 617.579321
# min                     0.000000                   0.000000
# 25%                     0.000000                  80.000000
# 50%                   194.990000                 264.485000
# 75%                   604.085000                 651.487500
# max                 12946.220000                8274.970000
#
#        TIME_0000_0600_ORDERS  TIME_0601_1200_ORDERS  TIME_1200_1800_ORDERS  \
# count            5000.000000            5000.000000            5000.000000
# mean                1.028800               3.746200               4.434000
# std                 2.174331               4.700234               5.044793
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               1.000000               1.000000
# 50%                 0.000000               2.000000               3.000000
# 75%                 1.000000               6.000000               7.000000
# max                34.000000              61.000000              58.000000
#
#        TIME_1801_2359_ORDERS  TIME_0000_0600_REVENUE  TIME_0601_1200_REVENUE  \
# count            5000.000000             5000.000000             5000.000000
# mean                3.661400              131.062636              486.863868
# std                 4.581894              331.289349              789.029911
# min                 0.000000                0.000000                0.000000
# 25%                 1.000000                0.000000               35.000000
# 50%                 2.000000                0.000000              236.440000
# 75%                 5.000000              131.282500              661.952500
# max                64.000000             7700.240000            23832.770000
#
#        TIME_1200_1800_REVENUE  TIME_1801_2359_REVENUE  Unnamed: 40  \
# count             5000.000000             5000.000000          0.0
# mean               584.731626              478.865710          NaN
# std                804.290026              743.244248          NaN
# min                  0.000000                0.000000          NaN
# 25%                 89.990000                1.000000          NaN
# 50%                299.840000              208.990000          NaN
# 75%                797.032500              620.117500          NaN
# max              17749.010000            12995.020000          NaN
#
#        Unnamed: 41
# count         1.00
# mean      33340.77
# std            NaN
# min       33340.77
# 25%       33340.77
# 50%       33340.77
# 75%       33340.77
# max       33340.77

# %% [markdown]
# ##### No of unique values for each column/feature-

# %%
for x in df.columns:
    print(x,'-',len(df[x].unique()))
# Out:
# CustomerID - 5000
# TOTAL_ORDERS - 85
# REVENUE - 4635
# AVERAGE_ORDER_VALUE - 4113
# CARRIAGE_REVENUE - 1175
# AVERAGESHIPPING - 567
# FIRST_ORDER_DATE - 1928
# LATEST_ORDER_DATE - 207
# AVGDAYSBETWEENORDERS - 3563
# DAYSSINCELASTORDER - 207
# MONDAY_ORDERS - 19
# TUESDAY_ORDERS - 22
# WEDNESDAY_ORDERS - 22
# THURSDAY_ORDERS - 23
# FRIDAY_ORDERS - 24
# SATURDAY_ORDERS - 24
# SUNDAY_ORDERS - 23
# MONDAY_REVENUE - 2151
# TUESDAY_REVENUE - 2201
# WEDNESDAY_REVENUE - 2262
# THURSDAY_REVENUE - 2582
# FRIDAY_REVENUE - 2378
# SATURDAY_REVENUE - 2149
# SUNDAY_REVENUE - 2573
# WEEK1_DAY01_DAY07_ORDERS - 27
# WEEK2_DAY08_DAY15_ORDERS - 34
# WEEK3_DAY16_DAY23_ORDERS - 33
# WEEK4_DAY24_DAY31_ORDERS - 32
# WEEK1_DAY01_DAY07_REVENUE - 3026
# WEEK2_DAY08_DAY15_REVENUE - 2900
# WEEK3_DAY16_DAY23_REVENUE - 2947
# WEEK4_DAY24_DAY31_REVENUE - 3386
# TIME_0000_0600_ORDERS - 22
# TIME_0601_1200_ORDERS - 41
# TIME_1200_1800_ORDERS - 41
# TIME_1801_2359_ORDERS - 36
# TIME_0000_0600_REVENUE - 1413
# TIME_0601_1200_REVENUE - 3203
# TIME_1200_1800_REVENUE - 3512
# TIME_1801_2359_REVENUE - 3128
# Unnamed: 40 - 1
# Unnamed: 41 - 2

# %% [markdown]
# ##### Counting Null (missing values) values-

# %%
# Check for missing values in all the columnns of the train_dataset
df.isnull().sum()
# Out:
# CustomerID                      0
# TOTAL_ORDERS                    0
# REVENUE                         0
# AVERAGE_ORDER_VALUE             0
# CARRIAGE_REVENUE                0
# AVERAGESHIPPING                 0
# FIRST_ORDER_DATE                0
# LATEST_ORDER_DATE               0
# AVGDAYSBETWEENORDERS            0
# DAYSSINCELASTORDER              0
# MONDAY_ORDERS                   0
# TUESDAY_ORDERS                  0
# WEDNESDAY_ORDERS                0
# THURSDAY_ORDERS                 0
# FRIDAY_ORDERS                   0
# SATURDAY_ORDERS                 0
# SUNDAY_ORDERS                   0
# MONDAY_REVENUE                  0
# TUESDAY_REVENUE                 0
# WEDNESDAY_REVENUE               0
# THURSDAY_REVENUE                0
# FRIDAY_REVENUE                  0
# SATURDAY_REVENUE                0
# SUNDAY_REVENUE                  0
# WEEK1_DAY01_DAY07_ORDERS        0
# WEEK2_DAY08_DAY15_ORDERS        0
# WEEK3_DAY16_DAY23_ORDERS        0
# WEEK4_DAY24_DAY31_ORDERS        0
# WEEK1_DAY01_DAY07_REVENUE       0
# WEEK2_DAY08_DAY15_REVENUE       0
# WEEK3_DAY16_DAY23_REVENUE       0
# WEEK4_DAY24_DAY31_REVENUE       0
# TIME_0000_0600_ORDERS           0
# TIME_0601_1200_ORDERS           0
# TIME_1200_1800_ORDERS           0
# TIME_1801_2359_ORDERS           0
# TIME_0000_0600_REVENUE          0
# TIME_0601_1200_REVENUE          0
# TIME_1200_1800_REVENUE          0
# TIME_1801_2359_REVENUE          0
# Unnamed: 40                  5000
# Unnamed: 41                  4999
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Dropping irrelevant "Unnamed" columns

# %%
df.drop(['Unnamed: 40', 'Unnamed: 41'], axis=1, inplace= True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### For finding correlation, creating two seperate list to store categorical column names and numerical column names respectively

# %%
# looping on whole dataset for geting list of categorical and numerical data column name and storing in respective list variable

categorical_list=[]
var_list=[]


for x in df.columns:
    if df[x].dtype=='object':
        categorical_list.append(x)
    elif df[x].dtype=='int64':
        var_list.append(x)
    elif df[x].dtype=='float64':
        var_list.append(x)
        
print('categorical' ,categorical_list)
print('numerical',var_list)
# Out:
# categorical []
# numerical ['CustomerID', 'TOTAL_ORDERS', 'REVENUE', 'AVERAGE_ORDER_VALUE', 'CARRIAGE_REVENUE', 'AVERAGESHIPPING', 'AVGDAYSBETWEENORDERS', 'DAYSSINCELASTORDER', 'MONDAY_ORDERS', 'TUESDAY_ORDERS', 'WEDNESDAY_ORDERS', 'THURSDAY_ORDERS', 'FRIDAY_ORDERS', 'SATURDAY_ORDERS', 'SUNDAY_ORDERS', 'MONDAY_REVENUE', 'TUESDAY_REVENUE', 'WEDNESDAY_REVENUE', 'THURSDAY_REVENUE', 'FRIDAY_REVENUE', 'SATURDAY_REVENUE', 'SUNDAY_REVENUE', 'WEEK1_DAY01_DAY07_ORDERS', 'WEEK2_DAY08_DAY15_ORDERS', 'WEEK3_DAY16_DAY23_ORDERS', 'WEEK4_DAY24_DAY31_ORDERS', 'WEEK1_DAY01_DAY07_REVENUE', 'WEEK2_DAY08_DAY15_REVENUE', 'WEEK3_DAY16_DAY23_REVENUE', 'WEEK4_DAY24_DAY31_REVENUE', 'TIME_0000_0600_ORDERS', 'TIME_0601_1200_ORDERS', 'TIME_1200_1800_ORDERS', 'TIME_1801_2359_ORDERS', 'TIME_0000_0600_REVENUE', 'TIME_0601_1200_REVENUE', 'TIME_1200_1800_REVENUE', 'TIME_1801_2359_REVENUE']

# %% [markdown]
# # Correlation Matrix
# #### A correlation matrix is a table shows correlation coefficients between variables.

# %%
# Correlation metrix using pandas
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_3f4d1_row0_col0,#T_3f4d1_row1_col1,#T_3f4d1_row2_col2,#T_3f4d1_row3_col3,#T_3f4d1_row4_col4,#T_3f4d1_row5_col5,#T_3f4d1_row6_col6,#T_3f4d1_row7_col7,#T_3f4d1_row8_col8,#T_3f4d1_row9_col9,#T_3f4d1_row10_col10,#T_3f4d1_row11_col11,#T_3f4d1_row12_col12,#T_3f4d1_row13_col13,#T_3f4d1_row14_col14,#T_3f4d1_row15_col15,#T_3f4d1_row16_col16,#T_3f4d1_row17_col17,#T_3f4d1_row18_col18,#T_3f4d1_row19_col19,#T_3f4d1_row20_col20,#T_3f4d1_row21_col21,#T_3f4d1_row22_col22,#T_3f4d1_row23_col23,#T_3f4d1_row24_col24,#T_3f4d1_row25_col25,#T_3f4d1_row26_col26,#T_3f4d1_row27_col27,#T_3f4d1_row28_col28,#T_3f4d1_row29_col29,#T_3f4d1_row30_col30,#T_3f4d1_row31_col31,#T_3f4d1_row32_col32,#T_3f4d1_row33_col33,#T_3f4d1_row34_col34,#T_3f4d1_row35_col35,#T_3f4d1_row36_col36,#T_3f4d1_row37_col37{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_3f4d1_row0_col1,#T_3f4d1_row0_col2,#T_3f4d1_row0_col3,#T_3f4d1_row0_col4,#T_3f4d1_row0_col8,#T_3f4d1_row0_col9,#T_3f4d1_row0_col10,#T_3f4d1_row0_col11,#T_3f4d1_row0_col12,#T_3f4d1_row0_col13,#T_3f4d1_row0_col14,#T_3f4d1_row0_col15,#T_3f4d1_row0_col16,#T_3f4d1_row0_col17,#T_3f4d1_row0_col18,#T_3f4d1_row0_col19,#T_3f4d1_row0_col20,#T_3f4d1_row0_col21,#T_3f4d1_row0_col22,#T_3f4d1_row0_col23,#T_3f4d1_row0_col24,#T_3f4d1_row0_col25,#T_3f4d1_row0_col26,#T_3f4d1_row0_col27,#T_3f4d1_row0_col28,#T_3f4d1_row0_col29,#T_3f4d1_row0_col30,#T_3f4d1_row0_col31,#T_3f4d1_row0_col32,#T_3f4d1_row0_col33,#T_3f4d1_row0_col34,#T_3f4d1_row0_col35,#T_3f4d1_row0_col36,#T_3f4d1_row0_col37,#T_3f4d1_row1_col0,#T_3f4d1_row1_col6,#T_3f4d1_row4_col6,#T_3f4d1_row6_col5,#T_3f4d1_row14_col7{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_3f4d1_row0_col5,#T_3f4d1_row4_col3,#T_3f4d1_row7_col21,#T_3f4d1_row16_col6,#T_3f4d1_row19_col0,#T_3f4d1_row27_col7,#T_3f4d1_row30_col5{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_3f4d1_row0_col6,#T_3f4d1_row3_col15,#T_3f4d1_row10_col34,#T_3f4d1_row12_col34,#T_3f4d1_row21_col34{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_3f4d1_row0_col7,#T_3f4d1_row3_col27,#T_3f4d1_row11_col15,#T_3f4d1_row13_col21,#T_3f4d1_row14_col17,#T_3f4d1_row30_col19,#T_3f4d1_row31_col21,#T_3f4d1_row34_col15,#T_3f4d1_row34_col17{
#             background-color:  #e2dad5;
#             color:  #000000;
#         }#T_3f4d1_row1_col2,#T_3f4d1_row9_col1,#T_3f4d1_row16_col2,#T_3f4d1_row23_col27,#T_3f4d1_row30_col34,#T_3f4d1_row35_col2,#T_3f4d1_row37_col33{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_3f4d1_row1_col3,#T_3f4d1_row7_col30,#T_3f4d1_row12_col3,#T_3f4d1_row31_col3,#T_3f4d1_row37_col7{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_3f4d1_row1_col4{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_3f4d1_row1_col5,#T_3f4d1_row6_col11,#T_3f4d1_row8_col6,#T_3f4d1_row18_col6,#T_3f4d1_row23_col5,#T_3f4d1_row29_col0,#T_3f4d1_row31_col7{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_3f4d1_row1_col7,#T_3f4d1_row2_col6,#T_3f4d1_row24_col0,#T_3f4d1_row27_col5,#T_3f4d1_row33_col5{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_3f4d1_row1_col8,#T_3f4d1_row1_col13,#T_3f4d1_row9_col16,#T_3f4d1_row15_col2,#T_3f4d1_row19_col2,#T_3f4d1_row22_col4,#T_3f4d1_row23_col32,#T_3f4d1_row31_col35,#T_3f4d1_row32_col23{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_3f4d1_row1_col9,#T_3f4d1_row20_col13,#T_3f4d1_row23_col4,#T_3f4d1_row29_col25,#T_3f4d1_row32_col36{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_3f4d1_row1_col10,#T_3f4d1_row17_col2,#T_3f4d1_row19_col12,#T_3f4d1_row24_col4,#T_3f4d1_row32_col4,#T_3f4d1_row33_col1,#T_3f4d1_row33_col37,#T_3f4d1_row36_col32{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_3f4d1_row1_col11,#T_3f4d1_row2_col15,#T_3f4d1_row2_col23,#T_3f4d1_row10_col4,#T_3f4d1_row23_col31,#T_3f4d1_row24_col31,#T_3f4d1_row26_col36{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_3f4d1_row1_col12,#T_3f4d1_row4_col24,#T_3f4d1_row4_col32,#T_3f4d1_row12_col19{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_3f4d1_row1_col14,#T_3f4d1_row2_col4,#T_3f4d1_row4_col10,#T_3f4d1_row10_col23,#T_3f4d1_row10_col25,#T_3f4d1_row11_col4,#T_3f4d1_row12_col32,#T_3f4d1_row24_col10,#T_3f4d1_row24_col23,#T_3f4d1_row31_col25,#T_3f4d1_row32_col2{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_3f4d1_row1_col15,#T_3f4d1_row8_col36,#T_3f4d1_row11_col12,#T_3f4d1_row12_col29,#T_3f4d1_row14_col13,#T_3f4d1_row18_col17,#T_3f4d1_row20_col35,#T_3f4d1_row24_col17,#T_3f4d1_row24_col27,#T_3f4d1_row24_col35,#T_3f4d1_row26_col9,#T_3f4d1_row28_col33,#T_3f4d1_row29_col8,#T_3f4d1_row29_col12,#T_3f4d1_row29_col31,#T_3f4d1_row30_col4,#T_3f4d1_row34_col2,#T_3f4d1_row35_col20,#T_3f4d1_row36_col8{
#             background-color:  #f7b99e;
#             color:  #000000;
#         }#T_3f4d1_row1_col16,#T_3f4d1_row9_col36,#T_3f4d1_row17_col24,#T_3f4d1_row17_col37,#T_3f4d1_row19_col24,#T_3f4d1_row20_col28,#T_3f4d1_row30_col1,#T_3f4d1_row33_col12,#T_3f4d1_row33_col32,#T_3f4d1_row35_col24,#T_3f4d1_row36_col9{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_3f4d1_row1_col17,#T_3f4d1_row1_col35,#T_3f4d1_row2_col12,#T_3f4d1_row13_col33,#T_3f4d1_row15_col27,#T_3f4d1_row18_col35,#T_3f4d1_row19_col26,#T_3f4d1_row23_col36,#T_3f4d1_row24_col36,#T_3f4d1_row26_col4,#T_3f4d1_row26_col15,#T_3f4d1_row26_col28,#T_3f4d1_row27_col18,#T_3f4d1_row28_col18,#T_3f4d1_row29_col4,#T_3f4d1_row29_col26,#T_3f4d1_row31_col13{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_3f4d1_row1_col18,#T_3f4d1_row2_col11,#T_3f4d1_row2_col14,#T_3f4d1_row9_col28,#T_3f4d1_row10_col29,#T_3f4d1_row14_col31,#T_3f4d1_row18_col4,#T_3f4d1_row18_col23,#T_3f4d1_row20_col23,#T_3f4d1_row23_col19,#T_3f4d1_row26_col20,#T_3f4d1_row27_col9,#T_3f4d1_row27_col24,#T_3f4d1_row28_col20,#T_3f4d1_row29_col9,#T_3f4d1_row29_col23,#T_3f4d1_row29_col33,#T_3f4d1_row36_col21{
#             background-color:  #f7b497;
#             color:  #000000;
#         }#T_3f4d1_row1_col19,#T_3f4d1_row2_col8,#T_3f4d1_row9_col33,#T_3f4d1_row15_col26,#T_3f4d1_row19_col28,#T_3f4d1_row21_col29,#T_3f4d1_row23_col14,#T_3f4d1_row24_col11,#T_3f4d1_row24_col22,#T_3f4d1_row26_col17,#T_3f4d1_row32_col14,#T_3f4d1_row32_col29,#T_3f4d1_row33_col9,#T_3f4d1_row36_col19{
#             background-color:  #f6a586;
#             color:  #000000;
#         }#T_3f4d1_row1_col20,#T_3f4d1_row19_col4,#T_3f4d1_row26_col32,#T_3f4d1_row33_col14,#T_3f4d1_row37_col15{
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }#T_3f4d1_row1_col21,#T_3f4d1_row8_col37,#T_3f4d1_row9_col37,#T_3f4d1_row14_col9,#T_3f4d1_row22_col17,#T_3f4d1_row24_col15,#T_3f4d1_row25_col26,#T_3f4d1_row26_col11,#T_3f4d1_row27_col14,#T_3f4d1_row27_col22,#T_3f4d1_row28_col13,#T_3f4d1_row33_col17,#T_3f4d1_row34_col1,#T_3f4d1_row36_col14,#T_3f4d1_row37_col14{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_3f4d1_row1_col22,#T_3f4d1_row1_col31{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_3f4d1_row1_col23,#T_3f4d1_row1_col32,#T_3f4d1_row25_col1,#T_3f4d1_row28_col2{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_3f4d1_row1_col24,#T_3f4d1_row23_col1,#T_3f4d1_row32_col1{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_3f4d1_row1_col25,#T_3f4d1_row2_col28,#T_3f4d1_row36_col2{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_3f4d1_row1_col26,#T_3f4d1_row8_col2,#T_3f4d1_row14_col23,#T_3f4d1_row18_col36,#T_3f4d1_row20_col1,#T_3f4d1_row22_col8,#T_3f4d1_row22_col10,#T_3f4d1_row22_col24,#T_3f4d1_row23_col22,#T_3f4d1

# %%
# Histogram using pandas 
df.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot:title={'center':'CustomerID'}>,
#         <AxesSubplot:title={'center':'TOTAL_ORDERS'}>,
#         <AxesSubplot:title={'center':'REVENUE'}>,
#         <AxesSubplot:title={'center':'AVERAGE_ORDER_VALUE'}>,
#         <AxesSubplot:title={'center':'CARRIAGE_REVENUE'}>,
#         <AxesSubplot:title={'center':'AVERAGESHIPPING'}>],
#        [<AxesSubplot:title={'center':'FIRST_ORDER_DATE'}>,
#         <AxesSubplot:title={'center':'LATEST_ORDER_DATE'}>,
#         <AxesSubplot:title={'center':'AVGDAYSBETWEENORDERS'}>,
#         <AxesSubplot:title={'center':'DAYSSINCELASTORDER'}>,
#         <AxesSubplot:title={'center':'MONDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'TUESDAY_ORDERS'}>],
#        [<AxesSubplot:title={'center':'WEDNESDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'THURSDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'FRIDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'SATURDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'SUNDAY_ORDERS'}>,
#         <AxesSubplot:title={'center':'MONDAY_REVENUE'}>],
#        [<AxesSubplot:title={'center':'TUESDAY_REVENUE'}>,
#         <AxesSubplot:title={'center':'WEDNESDAY_REVENUE'}>,
#         <AxesSubplot:title={'center':'THURSDAY_REVENUE'}>,
#         <AxesSubplot:title={'center':'FRIDAY_REVENUE'}>,
#         <AxesSubplot:title={'center':'SATURDAY_REVENUE'}>,
#         <AxesSubplot:title={'center':'SUNDAY_REVENUE'}>],
#        [<AxesSubplot:title={'center':'WEEK1_DAY01_DAY07_ORDERS'}>,
#         <AxesSubplot:title={'center':'WEEK2_DAY08_DAY15_ORDERS'}>,
#         <AxesSubplot:title={'center':'WEEK3_DAY16_DAY23_ORDERS'}>,
#         <AxesSubplot:title={'center':'WEEK4_DAY24_DAY31_ORDERS'}>,
#         <AxesSubplot:title={'center':'WEEK1_DAY01_DAY07_REVENUE'}>,
#         <AxesSubplot:title={'center':'WEEK2_DAY08_DAY15_REVENUE'}>],
#        [<AxesSubplot:title={'center':'WEEK3_DAY16_DAY23_REVENUE'}>,
#         <AxesSubplot:title={'center':'WEEK4_DAY24_DAY31_REVENUE'}>,
#         <AxesSubplot:title={'center':'TIME_0000_0600_ORDERS'}>,
#         <AxesSubplot:title={'center':'TIME_0601_1200_ORDERS'}>,
#         <AxesSubplot:title={'center':'TIME_1200_1800_ORDERS'}>,
#         <AxesSubplot:title={'center':'TIME_1801_2359_ORDERS'}>],
#        [<AxesSubplot:title={'center':'TIME_0000_0600_REVENUE'}>,
#         <AxesSubplot:title={'center':'TIME_0601_1200_REVENUE'}>,
#         <AxesSubplot:title={'center':'TIME_1200_1800_REVENUE'}>,
#         <AxesSubplot:title={'center':'TIME_1801_2359_REVENUE'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# group data by total order and plot count plot
df.groupby('TOTAL_ORDERS').count().plot(kind='bar',figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='TOTAL_ORDERS'>

# %%
# point plot for REVENUE and TOTAL_ORDERS columns
plt.figure(figsize=(20,6))
sns.pointplot(x='TOTAL_ORDERS',y='REVENUE',data=df,palette='rainbow')
plt.show()

# %% [markdown]
# ##### for highest, lowest and average amount of order placed-

# %%
df['REVENUE'].max()
# Out:
# 34847.4

# %%
df['REVENUE'].min()
# Out:
# 38.5

# %%
df['REVENUE'].mean()
# Out:
# 1681.5238400000312

# %% [markdown]
#  customer who generate revenue > avg revenue (above average category)

# %%
df1 =df[df['REVENUE']>1681.5238400000312]

# %%
df1.shape
# Out:
# (1845, 40)

# %% [markdown]
# customers who generate revenue < avg revenue (below average category)

# %%
df2 =df[df['REVENUE']<1681.5238400000312]

# %%
df2.shape
# Out:
# (3155, 40)

# %% [markdown]
# Maximum , minimum and avg amount of orders placed

# %%
df['TOTAL_ORDERS'].max()
# Out:
# 156

# %%
df['TOTAL_ORDERS'].min()
# Out:
# 1

# %%
df['TOTAL_ORDERS'].mean()
# Out:
# 12.8704

# %% [markdown]
# #### RFM:
#
# The RFM model is based on three quantitative factors:
#
# Recency: How recently a customer has made a purchase (DAYSSINCELASTORDER)<br>
#
# Frequency: How often a customer makes a purchase (AVGDAYSBETWEENORDERS)<br>
#
# Monetary Value: How much money a customer spends on purchases  (REVENUE)<br>
#
#
# <br>
# <br>
#
# -Champions Customers: Bought recently, buy often and spend the most => recency-latest | frequency-high | momentary-high <br>
#
# -Potential Customers: Recent customers with average frequency=> recency-latest | frequency-avg <br>
#
# -Need attention: Below average recency and frequency, Some time since they’ve purchased=> recency-low | frequency-low <br>

# %%
df['recency']= df['DAYSSINCELASTORDER']
df['frequency']= df['AVGDAYSBETWEENORDERS']
df['revenue']= df['REVENUE']

rfm= df[['CustomerID','revenue', 'frequency', 'recency']]
rfm.head(10)
# Out:
#    CustomerID   revenue  frequency  recency
# 0          22  11986.54      14.19        1
# 1          29  11025.96      15.89        1
# 2          83   7259.69      33.12        1
# 3          95   6992.27      21.11        1
# 4         124   6263.44       6.65        1
# 5         153   5841.24      46.57        1
# 6         187   5470.27      23.58        1
# 7         219   5200.53      13.06        1
# 8         258   4967.06      12.37        1
# 9         308   4726.38      31.29        1

# %% [markdown]
# Outliers-

# %%
plt.boxplot(rfm['revenue'])
plt.show()
plt.boxplot(rfm['frequency'])
plt.show()
plt.boxplot(rfm['recency'])
plt.show()

# %% [markdown]
# Outlier treatment (using interquantiloe range)-

# %%
q1_rev = rfm['revenue'].quantile(0.05)
q3_rev= rfm['revenue'].quantile(0.95)
IQR = q3_rev - q1_rev
rfm = rfm[(rfm['revenue'] >= q1_rev - 1.5*IQR) & (rfm['revenue'] <= q3_rev + 1.5*IQR)]

q1_freq = rfm['frequency'].quantile(0.05)
q3_freq = rfm['frequency'].quantile(0.95)
IQR = q3_freq - q1_freq
rfm = rfm[(rfm['frequency'] >= q1_freq - 1.5*IQR) & (rfm['frequency'] <= q3_freq + 1.5*IQR)]

q1_rec = rfm['recency'].quantile(0.05)
q3_rec = rfm['recency'].quantile(0.95)
IQR = q3_rec - q1_rec
rfm = rfm[(rfm['recency'] >= q1_rec - 1.5*IQR) & (rfm['recency'] <= q3_rec + 1.5*IQR)]

# %% [markdown]
# Scaling-

# %%
#Scaling the features
scale = StandardScaler()
cols = ['revenue', 'frequency', 'recency']
rfm_scaler = scale.fit_transform(rfm[cols])

# %%
rfm_scaled = pd.DataFrame(rfm_scaler)
rfm_scaled.columns = ['revenue', 'frequency', 'recency']
rfm_scaled.head()
# Out:
#     revenue  frequency   recency
# 0  6.032833  -0.574806 -1.078028
# 1  5.473669  -0.568268 -1.078028
# 2  3.281285  -0.502009 -1.078028
# 3  3.125618  -0.548194 -1.078028
# 4  2.701358  -0.603801 -1.078028

# %% [markdown]
# Hopkins Statistic- checks if points are well spaced for clustering

# %%
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
hopkins(rfm_scaled)
# Out:
# 0.9696560576456819

# %% [markdown]
# ##### Building Model (Hierarchial Cluster)

# %%
# complete linkage
plt.figure(figsize=(20,12))

mergings = linkage(rfm_scaled, method="complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
# clusters
cluster_labels = cut_tree(mergings, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 0, 0, ..., 1, 1, 2])

# %%
# assign cluster labels
pd.set_option('display.max_rows', None)
rfm['cluster_labels'] = cluster_labels
rfm.head(10)
# Out:
#    CustomerID   revenue  frequency  recency  cluster_labels
# 0          22  11986.54      14.19        1               0
# 1          29  11025.96      15.89        1               0
# 2          83   7259.69      33.12        1               0
# 3          95   6992.27      21.11        1               0
# 4         124   6263.44       6.65        1               0
# 5         153   5841.24      46.57        1               0
# 6         187   5470.27      23.58        1               0
# 7         219   5200.53      13.06        1               0
# 8         258   4967.06      12.37        1               0
# 9         308   4726.38      31.29        1               0

# %% [markdown]
# Analysing using box plots of 3 cluster: <br> <br>
# -The box in the box plot indicates the range in which the middle 50% of all the data lies <br>
# -the upper horizontal edge of box is q3 and similarly lower one is q1 25% data lies above and below q3 and q1 respectively (q3 to q1 is IQR) <br>
# -The solid line in box is median <br>
# -outside of wiskers are outliers <br>

# %%
# plots
sns.boxplot(x='cluster_labels', y='recency', data=rfm)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='recency'>

# %% [markdown]
# *above median line- customers with recency more than 50 (median) or less recent <br>
# *below median line- customers with recency less than 50 (median) or more recent <br>
#
# cluster 0 : 20-40 (20) q1 40-90 (50) q3  2:5 less recent coustomers than cluster 1 <br>
# cluster 1 : 0-80 (80) q1 80-200 (120) q3  2:3 <br>
# cluster 2 : 30-60 (30) q1 60-130 (70) q3  3:7 least recent coutomers of all or bad  recency (less recent orders) <br>
#
# cluster 1> cluster 0> cluster 2 (recency or R)

# %%
# plots
sns.boxplot(x='cluster_labels', y='frequency', data=rfm)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='frequency'>

# %% [markdown]
# Cluster 2 frequency is highest, then its cluster 0, then cluster 1 <br> <br>
# cluster 2 > cluster 0 > cluster 1 (Frequency or F)

# %%
# plots
sns.boxplot(x='cluster_labels', y='revenue', data=rfm)
# Out:
# <AxesSubplot:xlabel='cluster_labels', ylabel='revenue'>

# %% [markdown]
# cluster 2> cluster 1 > cluster 0 (revenue or M)

# %% [markdown]
# ##### Concluding <br>
#
# cluster 1> cluster 0> cluster 2 (recency or R) <br>
#
# cluster 2 > cluster 0 > cluster 1 (Frequency or F) <br>
#
# cluster 2> cluster 1 > cluster 0 (revenue or M) <br>
#
# -Champions Customers:=> recency-high | frequency-high | momentary-high;  So, cluster 2 <br>
#
# -Potential Customers:=> recency-high | frequency-avg; So, cluster 1 <br>
#
# -Need attention:=> recency-low | frequency-low; So, cluster 0 <br>
